# %% [markdown]
# ## Data Cleaning

# %%
import numpy as np 
import pandas as pd

# %%
# Reading Files
cpi = pd.read_excel("../data/raw/CPI.xlsx", header=2)
wpi = pd.read_excel("../data/raw/WPI.xlsx")

# %% [markdown]
# ### CPI Cleaning

# %%
cpi.columns = ['Date', 'CPI', 'Food', 'Food_Bev', 'Tobacco', 'Clothing', 'Housing', 'Fuel', 'Misc']

# %%
cpi = cpi.iloc[1:]

# %%
cpi.head()
# Out:
#                   Date   CPI  Food Food_Bev Tobacco Clothing Housing Fuel Misc
# 1  2011-01-01 00:00:00  89.5  93.5     92.3    82.4      NaN     NaN  NaN  NaN
# 2  2011-02-01 00:00:00  88.4  89.9     89.3    83.5      NaN     NaN  NaN  NaN
# 3  2011-03-01 00:00:00  88.4  88.9     88.6    85.1      NaN     NaN  NaN  NaN
# 4  2011-04-01 00:00:00  89.1  89.1     88.9    87.6      NaN     NaN  NaN  NaN
# 5  2011-05-01 00:00:00  89.8  89.7     89.5    88.8      NaN     NaN  NaN  NaN

# %%
cpi = cpi.reset_index(drop=True)

# %%
cpi.head()
# Out:
#                   Date   CPI  Food Food_Bev Tobacco Clothing Housing Fuel Misc
# 0  2011-01-01 00:00:00  89.5  93.5     92.3    82.4      NaN     NaN  NaN  NaN
# 1  2011-02-01 00:00:00  88.4  89.9     89.3    83.5      NaN     NaN  NaN  NaN
# 2  2011-03-01 00:00:00  88.4  88.9     88.6    85.1      NaN     NaN  NaN  NaN
# 3  2011-04-01 00:00:00  89.1  89.1     88.9    87.6      NaN     NaN  NaN  NaN
# 4  2011-05-01 00:00:00  89.8  89.7     89.5    88.8      NaN     NaN  NaN  NaN

# %%
cpi['Date'] = pd.to_datetime(cpi['Date'])
cpi['Date'] = cpi['Date'].dt.date

# %%
cpi = cpi.iloc[:, :5]

# %%
cpi.head()
# Out:
#          Date   CPI  Food Food_Bev Tobacco
# 0  2011-01-01  89.5  93.5     92.3    82.4
# 1  2011-02-01  88.4  89.9     89.3    83.5
# 2  2011-03-01  88.4  88.9     88.6    85.1
# 3  2011-04-01  89.1  89.1     88.9    87.6
# 4  2011-05-01  89.8  89.7     89.5    88.8

# %%
# Convert types
cpi['Date'] = pd.to_datetime(cpi['Date'])

cpi['CPI'] = pd.to_numeric(cpi['CPI'])
cpi['Food'] = pd.to_numeric(cpi['Food'])
cpi['Food_Bev'] = pd.to_numeric(cpi['Food_Bev'])
cpi['Tobacco'] = pd.to_numeric(cpi['Tobacco'])

# %%
cpi.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      180 non-null    datetime64[s]
#  1   CPI       180 non-null    float64
#  2   Food      180 non-null    float64
#  3   Food_Bev  180 non-null    float64
#  4   Tobacco   180 non-null    float64
# dtypes: datetime64[s](1), float64(4)
# memory usage: 7.2 KB

# %%
cpi = cpi[['Date', 'CPI']]

# %%
cpi.head()
# Out:
#         Date   CPI
# 0 2011-01-01  89.5
# 1 2011-02-01  88.4
# 2 2011-03-01  88.4
# 3 2011-04-01  89.1
# 4 2011-05-01  89.8

# %% [markdown]
# ### WPI Cleaning

# %%
wpi.head()
# Out:
#   Month Wholesale Price Index (WPI) - All Commodities            Unnamed: 2  \
# 0   NaN                    WPI Base 2011-12 : Monthly                   NaN
# 1   NaN                               All Commodities                   NaN
# 2   NaN                                           NaN                   NaN
# 3   NaN                                           NaN                   NaN
# 4   NaN                                  Index Values  Growth Rates (y-o-y)
#
#                            Unnamed: 3            Unnamed: 4     Unnamed: 5  \
# 0                                 NaN                   NaN            NaN
# 1  All Commodities : Primary Articles                   NaN            NaN
# 2                                 NaN                   NaN  Food Articles
# 3                                 NaN                   NaN            NaN
# 4                        Index Values  Growth Rates (y-o-y)   Index Values
#
# ...

# %%
wpi = pd.read_excel("../data/raw/WPI.xlsx", header=3)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 wpi = pd.read_excel("../data/raw/WPI.xlsx", header=3)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
# ...

# %%
wpi.head()

# %%
wpi.columns

# %%
wpi = pd.read_excel("../data/raw/WPI.xlsx", skiprows=3)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 wpi = pd.read_excel("../data/raw/WPI.xlsx", skiprows=3)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
# ...

# %%
wpi.head()

# %%
wpi = wpi[wpi.iloc[:,0] != 'Weight=>']

# %%
wpi.head()

# %%
wpi = wpi.iloc[:, :2]   # safest

# %%
wpi.head()
# Out:
#   Unnamed: 0    Unnamed: 1
# 0        NaN           NaN
# 1        NaN  Index Values
# 3   Jan-2012           NaN
# 4   Feb-2012           NaN
# 5   Mar-2012           NaN

# %%
wpi.columns = ['Date', 'WPI']

# %%
wpi = wpi.iloc[2:]

# %%
wpi = wpi.reset_index(drop=True)

# %%
wpi.head()
# Out:
#   Month Wholesale Price Index (WPI) - All Commodities            Unnamed: 2  \
# 0   NaN                    WPI Base 2011-12 : Monthly                   NaN
# 1   NaN                               All Commodities                   NaN
# 2   NaN                                           NaN                   NaN
# 3   NaN                                           NaN                   NaN
# 4   NaN                                  Index Values  Growth Rates (y-o-y)
#
#                            Unnamed: 3            Unnamed: 4     Unnamed: 5  \
# 0                                 NaN                   NaN            NaN
# 1  All Commodities : Primary Articles                   NaN            NaN
# 2                                 NaN                   NaN  Food Articles
# 3                                 NaN                   NaN            NaN
# 4                        Index Values  Growth Rates (y-o-y)   Index Values
#
# ...

# %%
wpi.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    183 non-null    str
#  1   WPI     167 non-null    object
# dtypes: object(1), str(1)
# memory usage: 3.1+ KB

# %%
wpi.count()
# Out:
# Date    183
# WPI     167
# dtype: int64

# %%
wpi['Date'] = pd.to_datetime(wpi['Date'], format='%b-%Y', errors='coerce')
wpi['WPI'] = pd.to_numeric(wpi['WPI'], errors='coerce')

# %%
wpi['WPI'] = wpi['WPI'].ffill()

# %%
wpi.head()

# %%
wpi['WPI'] = wpi['WPI'].ffill().bfill()

# %%
wpi = wpi[wpi['Date'] >= '2012-04-01']

# %%
wpi = wpi.reset_index(drop=True)

# %%
cpi.head()
wpi.head()
# Out:
#         Date    WPI
# 0 2012-04-01  104.7
# 1 2012-05-01  105.3
# 2 2012-06-01  105.3
# 3 2012-07-01  106.2
# 4 2012-08-01  106.9

# %%
cpi.head()
# Out:
#         Date   CPI
# 2 2011-03-01  88.4
# 3 2011-04-01  89.1
# 4 2011-05-01  89.8
# 5 2011-06-01  90.6
# 6 2011-07-01  91.8

# %%
cpi = cpi[cpi['Date'] >= '2012-04-01']
cpi = cpi.reset_index(drop=True)

# %%
df = pd.merge(cpi, wpi, on='Date', how='inner')

# %%
df.to_csv("../data/processed/final_dataset.csv", index=False)
